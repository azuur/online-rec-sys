# %%
PATH = "/home/adrian/Documents/projects/online-learning-simple-demo/data/raw/mpst_full_data.csv"

import pandas as pd

raw_data = pd.read_csv(PATH, nrows=1_000)

# %%
raw_data
# Out:
#        imdb_id                                          title  \
# 0    tt0057603                        I tre volti della paura
# 1    tt1733125  Dungeons & Dragons: The Book of Vile Darkness
# 2    tt0033045                     The Shop Around the Corner
# 3    tt0113862                             Mr. Holland's Opus
# 4    tt0086250                                       Scarface
# ..         ...                                            ...
# 995  tt0055058                                          Konga
# 996  tt0082951                                    The Prowler
# 997  tt0094812                                    Bull Durham
# 998  tt0039302                                   Dark Passage
# 999  tt0095238                                The Good Mother
#
#                                          plot_synopsis  \
# 0    Note: this synopsis is for the orginal Italian...
# 1    Two thousand years ago, Nhagruul the Foul, a s...
# ...
